# %%
from nltk import WordNetLemmatizer
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in ./.venv/lib/python3.9/site-packages (3.8.1)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.9/site-packages (from nltk) (2024.5.10)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.9/site-packages (from nltk) (4.66.4)

# %%
paragraph ="""
Narendra Modi (born September 17, 1950, Vadnagar, India) is an Indian politician and government official who rose to become a senior leader of the Bharatiya Janata Party (BJP). In 2014 he led his party to victory in elections to the Lok Sabha (lower chamber of the Indian parliament), after which he was sworn in as prime minister of India. Prior to that he had served (2001–14) as chief minister (head of government) of Gujarat state in western India. The Modi-led BJP (and the BJP-led NDA alliance) won majority again in the 2019 general election. Modi is looking to win a third term in the 2024 Lok Sabha elections.
Early life and political career

Modi was raised in a small town in northern Gujarat, and he completed an M.A. degree in political science from Gujarat University in Ahmadabad. He joined the pro-Hindu Rashtriya Swayamsevak Sangh (RSS) organization in the early 1970s and set up a unit of the RSS’s students’ wing, the Akhil Bharatiya Vidyarthi Parishad, in his area. Modi rose steadily in the RSS hierarchy, and his association with the organization significantly benefited his subsequent political career.

Modi joined the BJP in 1987, and a year later he was made the general secretary of the Gujarat branch of the party. He was instrumental in greatly strengthening the party’s presence in the state in succeeding years. In 1990 Modi was one of the BJP members who participated in a coalition government in the state, and he helped the BJP achieve success in the 1995 state legislative assembly elections that in March allowed the party to form the first-ever BJP-controlled government in India. The BJP’s control of the state government was relatively short-lived, however, ending in September 1996.
Political ascent and term as chief minister of Gujarat

In 1995 Modi was made the secretary of the BJP’s national organization in New Delhi, and three years later he was appointed its general secretary. He remained in that office for another three years, but in October 2001 he replaced the incumbent Gujarat chief minister, fellow BJP member Keshubhai Patel, after Patel had been held responsible for the state government’s poor response in the aftermath of the massive Bhuj earthquake in Gujarat earlier that year that killed more than 20,000 people. Modi entered his first-ever electoral contest in a February 2002 by-election that won him a seat in the Gujarat state assembly.

Modi’s political career thereafter remained a mixture of deep controversy and self-promoted achievements. His role as chief minister during communal riots that engulfed Gujarat in 2002 was particularly questioned. He was accused of condoning the violence or, at least, of doing little to stop the killing of more than 1,000 people, mostly Muslims, that ensued after dozens of Hindu passengers died when their train was set on fire in the city of Godhra. In 2005 the United States declined to issue him a diplomatic visa on the grounds that he was responsible for the 2002 riots, and the United Kingdom also criticized his role in 2002. Although in the succeeding years Modi himself escaped any indictment or censure—either by the judiciary or by investigative agencies—some of his close associates were found guilty of complicity in the 2002 events and received lengthy jail sentences. Modi’s administration was also accused of involvement in extrajudicial killings (variously termed “encounters” or “fake encounters”) by police or other authorities. One such case, in 2004, involved the deaths of a woman and three men whom officials said were members of Lashkar-e-Taiba (a Pakistan-based terrorist organization that was involved in the 2008 Mumbai terrorist attacks) and were alleged to have been plotting to assassinate Modi.

Modi’s repeated political success in Gujarat, however, made him an indispensable leader within the BJP hierarchy and led to his reintegration into the political mainstream. Under his leadership, the BJP secured a significant victory in the December 2002 legislative assembly elections, winning 127 of the 182 seats in the chamber (including a seat for Modi). Projecting a manifesto for growth and development in Gujarat, the BJP was again victorious in the 2007 state assembly elections, with a seat total of 117, and the party prevailed again in the 2012 polls, garnering 115 seats. Both times Modi won his contests and returned as chief minister.
"""

# %%
paragraph
# Out:
# '\nNarendra Modi (born September 17, 1950, Vadnagar, India) is an Indian politician and government official who rose to become a senior leader of the Bharatiya Janata Party (BJP). In 2014 he led his party to victory in elections to the Lok Sabha (lower chamber of the Indian parliament), after which he was sworn in as prime minister of India. Prior to that he had served (2001–14) as chief minister (head of government) of Gujarat state in western India. The Modi-led BJP (and the BJP-led NDA alliance) won majority again in the 2019 general election. Modi is looking to win a third term in the 2024 Lok Sabha elections.\nEarly life and political career\n\nModi was raised in a small town in northern Gujarat, and he completed an M.A. degree in political science from Gujarat University in Ahmadabad. He joined the pro-Hindu Rashtriya Swayamsevak Sangh (RSS) organization in the early 1970s and set up a unit of the RSS’s students’ wing, the Akhil Bharatiya Vidyarthi Parishad, in his area. Modi rose steadily in the RSS hierarchy, and his association with the organization significantly benefited his subsequent political career.\n\nModi joined the BJP in 1987, and a year later he was made the general secretary of the Gujarat branch of the party. He was instrumental in greatly strengthening the party’s presence in the state in succeeding years. In 1990 Modi was one of the BJP members who participated in a coalition government in the state, and he helped the BJP achieve success in the 1995 state legislative assembly elections that in March allowed the party to form the first-ever BJP-controlled government in India. The BJP’s control of the state government was relatively short-lived, however, ending in September 1996.\nPolitical ascent and term as chief minister of Gujarat\n\nIn 1995 Modi was made the secretary of the BJP’s national organization in New Delhi, and three years later he was appointed its general secretary. He remained in that office for another three years, but in October 2001 he replaced the incumbent Gujarat chief minister, fellow BJP member Keshubhai Patel, after Patel had been held responsible for the state government’s poor response in the aftermath of the massive Bhuj earthquake in Gujarat earlier that year that killed more than 20,000 people. Modi entered his first-ever electoral contest in a February 2002 by-election that won him a seat in the Gujarat state assembly.\n\nModi’s political career thereafter remained a mixture of deep controversy and self-promoted achievements. His role as chief minister during communal riots that engulfed Gujarat in 2002 was particularly questioned. He was accused of condoning the violence or, at least, of doing little to stop the killing of more than 1,000 people, mostly Muslims, that ensued after dozens of Hindu passengers died when their train was set on fire in the city of Godhra. In 2005 the United States declined to issue him a diplomatic visa on the grounds that he was responsible for the 2002 riots, and the United Kingdom also criticized his role in 2002. Although in the succeeding years Modi himself escaped any indictment or censure—either by the judiciary or by investigative agencies—some of his close associates were found guilty of complicity in the 2002 events and received lengthy jail sentences. Modi’s administration was also accused of involvement in extrajudicial killings (variously termed “encounters” or “fake encounters”) by police or other authorities. One such case, in 2004, involved the deaths of a woman and three men whom officials said were members of Lashkar-e-Taiba (a Pakistan-based terrorist organization that was involved in the 2008 Mumbai terrorist attacks) and were alleged to have been plotting to assassinate Modi.\n\nModi’s repeated political success in Gujarat, however, made him an indispensable leader within the BJP hierarchy and led to his reintegration into the political mainstream. Under his leadership, the BJP secured a significant victory in the December 2 ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
'''import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()'''
# Out:
# 'import nltk\nimport ssl\n\ntry:\n    _create_unverified_https_context = ssl._create_unverified_context\nexcept AttributeError:\n    pass\nelse:\n    ssl._create_default_https_context = _create_unverified_https_context\n\nnltk.download()'

# %%
##Convert paragraph to sentences
nltk.download('punkt')
sentences = nltk.sent_tokenize(paragraph)
# Out:
# [nltk_data] Downloading package punkt to /Users/sanju/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
len(sentences)
# Out:
# 27

# %%
lemmatizer = WordNetLemmatizer()
import re
corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [lemmatizer.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    print(review)
    corpus.append(review)
# Out:
# narendra modi born september vadnagar india indian politician government official rose become senior leader bharatiya janata party bjp
# led party victory election lok sabha lower chamber indian parliament sworn prime minister india
# prior served chief minister head government gujarat state western india
# modi led bjp bjp led nda alliance majority general election
# modi looking win third term lok sabha election
# early life political career modi raised small town northern gujarat completed
# degree political science gujarat university ahmadabad
# joined pro hindu rashtriya swayamsevak sangh r organization early set unit r student wing akhil bharatiya vidyarthi parishad area
# modi rose steadily r hierarchy association organization significantly benefited subsequent political career
# modi joined bjp year later made general secretary gujarat branch party
# instrumental greatly strengthening party presence state succeeding year
# modi one bjp member participated coalition government state helped bjp achieve success state legislative assembly election march allowed party form first ever bjp controlled government india
# bjp control state government relatively short lived however ending september
# political ascent term chief minister gujarat modi made secretary bjp national organization new delhi three year later appointed general secretary
# remained office another three year october replaced incumbent gujarat chief minister fellow bjp member keshubhai patel patel held responsible state government poor response aftermath massive bhuj earthquake gujarat earlier year killed people
# modi entered first ever electoral contest february election seat gujarat state assembly
# modi political career thereafter remained mixture deep controversy self promoted achievement
# role chief minister communal riot engulfed gujarat particularly questioned
# accused condoning violence least little stop killing people mostly muslim ensued dozen hindu passenger died train set fire city godhra
# united state declined issue diplomatic visa ground responsible riot united kingdom also criticized role
# although succeeding year modi escaped indictment censure either judiciary investigative agency close associate found guilty complicity event received lengthy jail sentence
# modi administration also accused involvement extrajudicial killing variously termed encounter fake encounter police authority
# one case involved death woman three men official said member lashkar e taiba pakistan based terrorist organization involved mumbai terrorist attack alleged plotting assassinate modi
# modi repeated political success gujarat however made indispensable leader within bjp hierarchy led reintegration political mainstream
# leadership bjp secured significant victory december legislative assembly election winning seat chamber including seat modi
# projecting manifesto growth development gujarat bjp victorious state assembly election seat total party prevailed poll garnering seat
# time modi contest returned chief minister

# %%
corpus
# Out:
# ['narendra modi born september vadnagar india indian politician government official rose become senior leader bharatiya janata party bjp',
#  'led party victory election lok sabha lower chamber indian parliament sworn prime minister india',
#  'prior served chief minister head government gujarat state western india',
#  'modi led bjp bjp led nda alliance majority general election',
#  'modi looking win third term lok sabha election',
#  'early life political career modi raised small town northern gujarat completed',
#  'degree political science gujarat university ahmadabad',
#  'joined pro hindu rashtriya swayamsevak sangh r organization early set unit r student wing akhil bharatiya vidyarthi parishad area',
#  'modi rose steadily r hierarchy association organization significantly benefited subsequent political career',
#  'modi joined bjp year later made general secretary gujarat branch party',
#  'instrumental greatly strengthening party presence state succeeding year',
#  'modi one bjp member participated coalition government state helped bjp achieve success state legislative assembly election march allowed party form first ever bjp controlled government india',
#  'bjp control state government relatively short lived however ending september',
#  'political ascent term chief minister gujarat modi made secretary bjp national organization new delhi three year later appointed general secretary',
#  'remained office another three year october replaced incumbent gujarat chief minister fellow bjp member keshubhai patel patel held responsible state government poor response aftermath massive bhuj earthquake gujarat earlier year killed people',
#  'modi entered first ever electoral contest february election seat gujarat state assembly',
#  'modi political career thereafter remained mixture deep controversy self promoted achievement',
#  'role chief minister communal riot engulfed gujarat particularly questioned',
#  'accused condoning violence least little stop killing people mostly muslim ensued dozen hindu passenger died train set fire city godhra',
#  'united state declined issue diplomatic visa ground responsible riot united kingdom also criticized role',
#  'although succeeding year modi escaped indictment censure either judiciary investigative agency close associate found guilty complicity event received lengthy jail sentence',
#  'modi administration also accused involvement extrajudicial killing variously termed encounter fake encounter police authority',
#  'one case involved death woman three men official said member lashkar e taiba pakistan based terrorist organization involved mumbai terrorist attack alleged plotting assassinate modi',
#  'modi repeated political success gujarat however made indispensable leader within bjp hierarchy led reintegration political mainstream',
#  'leadership bjp secured significant victory december legislative assembly election winning seat chamber including seat modi',
#  'projecting manifesto growth development gujarat bjp victorious state assembly election seat total party prevailed poll garnering seat',
#  'time modi contest returned chief minister']

# %%
#Bag of Words
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(binary=True,ngram_range=(1,3))

# %%
X = cv.fit_transform(corpus)

# %%
cv.vocabulary_
# Out:
# {'narendra': 550,
#  'modi': 512,
#  'born': 107,
#  'september': 756,
#  'vadnagar': 874,
#  'india': 359,
#  'indian': 362,
#  'politician': 640,
#  'government': 284,
#  'official': 571,
#  'rose': 715,
#  'become': 69,
#  'senior': 752,
#  'leader': 424,
#  'bharatiya': 75,
#  'janata': 392,
#  'party': 603,
#  'bjp': 83,
#  'narendra modi': 551,
#  'modi born': 515,
#  'born september': 108,
#  'september vadnagar': 757,
#  'vadnagar india': 875,
#  'india indian': 360,
#  'indian politician': 365,
#  'politician government': 641,
#  'government official': 288,
#  'official rose': 572,
#  'rose become': 716,
#  'become senior': 70,
#  'senior leader': 753,
#  'leader bharatiya': 425,
#  'bharatiya janata': 76,
#  'janata party': 393,
#  'party bjp': 604,
#  'narendra modi born': 552,
#  'modi born september': 516,
#  'born september vadnagar': 109,
#  'september vadnagar india': 758,
#  'vadnagar india indian': 876,
#  'india indian politician': 361,
#  'indian politician government': 366,
#  'politician government official': 642,
#  'government official rose': 289,
#  'official rose become': 573,
#  'rose become senior': 717,
#  'become senior leader': 71,
#  'senior leader bharatiya': 754,
#  'leader bharatiya janata': 426,
#  'bharatiya janata party': 77,
#  'janata party bjp': 394,
#  'led': 435,
#  'victory': 883,
#  'election': 212,
#  'lok': 459,
#  'sabha': 720,
#  'lower': 466,
#  'chamber': 123,
#  'parliament': 595,
#  'sworn': 821,
#  'prime': 655,
#  'minister': 499,
#  'led party': 440,
#  'party victory': 611,
#  'victory election': 886,
#  'election lok': 213,
#  'lok sabha': 460,
#  'sabha lower': 722,
#  'lower chamber': 467,
#  'chamber indian': 126,
#  'indian parliament': 363,
#  'parliament sworn': 596,
#  'sworn prime': 822,
#  'prime minister': 656,
#  'minister india': 508,
#  'led party victory': 441,
#  'party victory election': 612,
#  'victory election lok': 887,
#  'election lok sabha': 214,
#  'lok sabha lower': 462,
#  'sabha lower chamber': 723,
#  'lower chamber indian': 468,
#  'chamber indian parliament': 127,
#  'indian parliament sworn': 364,
#  'parliament sworn prime': 597,
#  'sworn prime minister': 823,
#  'prime minister india': 657,
#  'prior': 658,
#  'served': 759,
#  'chief': 128,
#  'head': 329,
#  'gujarat': 308,
#  'state': 779,
#  'western': 897,
#  'prior served': 659,
#  'served chief': 760,
#  'chief minister': 129,
#  'minister head': 506,
#  'head government': 330,
#  'government gujarat': 285,
#  'gujarat state': 324,
#  'state western': 793,
#  'western india': 898,
#  'prior served chief': 660,
#  'served chief minister': 761,
#  'chief minister head': 133,
#  'minister head government': 507,
#  'head government gujarat': 331,
#  'government gujarat state': 286,
#  'gujarat state western': 326,
#  'state western india': 794,
#  'nda': 556,
#  'alliance': 25,
#  'majority': 477,
#  'general': 279,
#  'modi led': 525,
#  'led bjp': 436,
#  'bjp bjp': 86,
#  'bjp led': 94,
#  'led nda': 438,
#  'nda alliance': 557,
#  'alliance majority': 26,
#  'majority general': 478,
#  'general election': 280,
#  'modi led bjp': 526,
#  'led bjp bjp': 437,
#  'bjp bjp led': 87,
#  'bjp led nda': 95,
#  'led nda alliance': 439,
#  'nda alliance majority': 558,
#  'alliance majority general': 27,
#  'majority general election': 479,
#  'looking': 463,
#  'win': 899,
#  'third': 843,
#  'term': 827,
#  'modi looking': 527,
#  'looking win': 464,
#  'win third': 900,
#  'third term': 844,
#  'term lok': 830,
#  'sabha election': 721,
#  'modi looking win': 528,
#  'looking win third': 465,
#  'win third term': 901,
#  'third term lok': 845,
#  'term lok sabha': 831,
#  'lok sabha election': 461,
#  'early': 201,
#  'life': 450,
#  'political': 629,
#  'career': 112,
#  'raised': 670,
#  'small': 776,
#  'town': 858,
#  'northern': 562,
#  'completed': 145,
#  'early life': 202,
#  'life political': 451,
#  'political career': 632,
#  'career modi': 113,
#  'modi raised': 535,
#  'raised small': 671,
#  'small town': 777,
#  'town northern': 859,
#  'northern gujarat': 563,
#  'gujarat completed': 315,
#  'early life political': 203,
#  'life political career': 452,
#  'political career modi': 633,
#  'career modi raised': 114,
#  'modi raised small': 536,
#  'raised small town': 672,
#  'small town northern': 778,
#  'town northern gujarat': 860,
#  'northern gujarat completed': 564,
#  'degree': 180,
#  'science': 730,
#  'university': 872,
#  'ahmadabad': 18,
#  'degree political': 181,
#  'political science': 636,
#  'science gujarat': 731,
#  'gujarat university': 327,
#  'university ahmadabad': 873,
#  'degree political science': 182,
#  'political science gujarat': 637,
#  'science gujarat university': 732,
#  'gujarat university ahmadabad': 328,
#  'joined': 395,
#  'pro': 661,
#  'hindu': 343,
#  'rashtriya': 673,
#  'swayamsevak': 818,
#  'sangh': 727,
#  'organization': 581,
#  'set': 762,
#  'unit': 864,
#  'student': 804,
#  'wing': 902,
#  'akhil': 19,
#  'vidyarthi': 888,
#  'parishad': 593,
#  'area': 45,
#  'joined pro': 398,
#  'pro hindu': 662,
#  'hindu rashtriya': 346,
#  'rashtriya swayamsevak': 674,
#  'swayamsevak sangh': 819,
#  'sangh organization': 728,
#  'organization early': 582,
#  'early set': 204,
#  'set unit': 765,
#  'unit student': 865,
#  'student wing': 805,
#  'wing akhil': 903,
#  'akhil bharatiya': 20,
#  'bharatiya vidyarthi': 78,
#  'vidyarthi parishad': 889,
#  'parishad area': 594,
#  'joined pro hindu': 399,
#  'pro hindu rashtriya': 663,
#  'hindu rashtriya swayamsevak': 347,
#  'rashtriya swayamsevak sangh': 675,
#  'swayamsevak sangh organization': 820,
#  'sangh organization early': 729,
#  'organization early set': 583,
#  'early set unit': 205,
#  'set unit student': 766,
#  'unit student wing': 866,
#  'student wing akhil': 806,
#  'wing akhil bharatiya': 904,
#  'akhil bharatiya vidyarthi': 21,
#  'bharatiya vidyarthi parishad': 79,
#  'vidyarthi parishad area': 890,
#  'steadily': 795,
#  'hierarchy': 338,
#  'association': 59,
#  'significantly': 773,
#  'benefited': 72,
#  'subsequent': 807,
#  'modi rose': 539,
#  'rose steadily': 718,
#  'steadily hierarchy': 796,
#  'hierarchy association': 339,
#  'association organization': 60,
#  'organization significantly': 588,
#  'significantly benefited': 774,
#  'benefited subsequent': 73,
#  'subsequent political': 808,
#  'modi rose steadily': 540,
#  'rose steadily hierarchy': 719,
#  'steadily hierarchy association': 797,
#  'hierarchy association organization': 340,
#  'association organization significantly': 61,
#  'organization significantly benefited': 589,
#  'significantly benefited subsequent': 775,
#  'benefited subsequent political': 74,
#  'subsequent political career': 809,
#  'year': 914,
#  'later': 419,
#  'made': 469,
#  'secretary': 741,
#  'branch': 110,
#  'modi joined': 523,
#  'joined bjp': 396,
#  'bjp year': 105,
#  'year later': 917,
#  'later made': 422,
#  'made general': 470,
#  'general secretary': 281,
#  'secretary gujarat': 744,
#  'gujarat branch': 311,
#  'branch party': 111,
#  'modi joined bjp': 524,
#  'joined bjp year': 397,
#  'bjp year later': 106,
#  'year later made': 919,
#  'later made general': 423,
#  'made general secretary': 471,
#  'general secretary gujarat': 282,
#  'secretary gujarat branch': 745,
#  'gujarat branch party': 312,
#  'instrumental': 373,
#  'greatly': 296,
#  'strengthening': 801,
#  'presence': 649,
#  'succeeding': 810,
#  'instrumental greatly': 374,
#  'greatly strengthening': 297,
#  'strengthening party': 802,
#  'party presence': 607,
#  'presence state': 650,
#  'state succeeding': 791,
#  'succeeding year': 811,
#  'instrumental greatly strengthening': 375,
#  'greatly strengthening party': 298,
#  'strengthening party presence': 803,
#  'party presence state': 608,
#  'presence state succeeding': 651,
#  'state succeeding year': 792,
#  'one': 576,
#  'member': 489,
#  'participated': 598,
#  'coalition': 139,
#  'helped': 335,
#  'achieve': 5,
#  'success': 813,
#  'legislative': 444,
#  'assembly': 51,
#  'march': 483,
#  'allowed': 28,
#  'form': 271,
#  'first': 267,
#  'ever': 247,
#  'controlled': 160,
#  'modi one': 531,
#  'one bjp': 577,
#  'bjp member': 96,
#  'member participated': 494,
#  'participated coalition': 599,
#  'coalition government': 140,
#  'government state': 294,
#  'state helped': 787,
#  'helped bjp': 336,
#  'bjp achieve': 84,
#  'achieve success': 6,
#  'success state': 816,
#  'state legislative': 789,
#  'legislative assembly': 445,
#  'assembly election': 52,
#  'election march': 215,
#  'march allowed': 484,
#  'allowed party': 29,
#  'party form': 605,
#  'form first': 272,
#  'first ever': 268,
#  'ever bjp': 248,
#  'bjp controlled': 90,
#  'controlled government': 161,
#  'government india': 287,
#  'modi one bjp': 532,
#  'one bjp member': 578,
#  'bjp member participated': 98,
#  'member participated coalition': 495,
#  'participated coalition government': 600,
#  'coalition government state': 141,
#  'government state helped': 295,
#  'state helped bjp': 788,
#  'helped bjp achieve': 337,
#  'bjp achieve success': 85,
#  'achieve success state': 7,
#  'success state legislative': 817,
#  'state legislative assembly': 790,
#  'legislative assembly election': 446,
#  'assembly election march': 53,
#  'election march allowed': 216,
#  'march allowed party': 485,
#  'allowed party form': 30,
#  'party form first': 606,
#  'form first ever': 273,
#  'first ever bjp': 269,
#  'ever bjp controlled': 249,
#  'bjp controlled government': 91,
#  'controlled government india': 162,
#  'control': 157,
#  'relatively': 682,
#  'short': 767,
#  'lived': 456,
#  'however': 348,
#  'ending': 230,
#  'bjp control': 88,
#  'control state': 158,
#  'state government': 784,
#  'government relatively': 292,
#  'relatively short': 683,
#  'short lived': 768,
#  'lived however': 457,
#  'however ending': 349,
#  'ending september': 231,
#  'bjp control state': 89,
#  'control state government': 159,
#  'state government relatively': 786,
#  'government relatively short': 293,
#  'relatively short lived': 684,
#  'short lived however': 769,
#  'lived however ending': 458,
#  'however ending september': 350,
#  'ascent': 46,
#  'national': 553,
#  'new': 559,
#  'delhi': 183,
#  'three': 846,
#  'appointed': 42,
#  'political ascent': 630,
#  'ascent term': 47,
#  'term chief': 828,
#  'minister gujarat': 504,
#  'gujarat modi': 320,
#  'modi made': 529,
#  'made secretary': 474,
#  'secretary bjp': 742,
#  'bjp national': 99,
#  'national organization': 554,
#  'organization new': 586,
#  'new delhi': 560,
#  'delhi three': 184,
#  'three year': 849,
#  'later appointed': 420,
#  'appointed general': 43,
#  'political ascent term': 631,
#  'ascent term chief': 48,
#  'term chief minister': 829,
#  'chief minister gujarat': 132,
#  'minister gujarat modi': 505,
#  'gujarat modi made': 321,
#  'modi made secretary': 530,
#  'made secretary bjp': 475,
#  'secretary bjp national': 743,
#  'bjp national organization': 100,
#  'national organization new': 555,
#  'organization new delhi': 587,
#  'new delhi three': 561,
#  'delhi three year': 185,
#  'three year later': 850,
#  'year later appointed': 918,
#  'later appointed general': 421,
#  'appointed general secretary': 44,
#  'remained': 685,
#  'office': 568,
#  'another': 39,
#  'october': 565,
#  'replaced': 693,
#  'incumbent': 356,
#  'fellow': 261,
#  'keshubhai': 403,
#  'patel': 616,
#  'held': 332,
#  'responsible': 699,
#  'poor': 646,
#  'response': 696,
#  'aftermath': 12,
#  'massive': 486,
#  'bhuj': 80,
#  'earthquake': 206,
#  'earlier': 198,
#  'killed': 406,
#  'people': 621,
#  'remained office': 688,
#  'office another': 569,
#  'another three': 40,
#  'year october': 922,
#  'october replaced': 566,
#  'replaced incumbent': 694,
#  'incumbent gujarat': 357,
#  'gujarat chief': 313,
#  'minister fellow': 502,
#  'fellow bjp': 262,
#  'member keshubhai': 490,
#  'keshubhai patel': 404,
#  'patel patel': 619,
#  'patel held': 617,
#  'held responsible': 333,
#  'responsible state': 702,
#  'government poor': 290,
#  'poor response': 647,
#  'response aftermath': 697,
#  'aftermath massive': 13,
#  'massive bhuj': 487,
#  'bhuj earthquake': 81,
#  'earthquake gujarat': 207,
#  'gujarat earlier': 316,
#  'earlier year': 199,
#  'year killed': 915,
#  'killed people': 407,
#  'remained office another': 689,
#  'office another three': 570,
#  'another three year': 41,
#  'three year october': 851,
#  'year october replaced': 923,
#  'october replaced incumbent': 567,
#  'replaced incumbent gujarat': 695,
#  'incumbent gujarat chief': 358,
#  'gujarat chief minister': 314,
#  'chief minister fellow': 131,
#  'minister fellow bjp': 503,
#  'fellow bjp member': 263,
#  'bjp member keshubhai': 97,
#  'member keshubhai patel': 491,
#  'keshubhai patel patel': 405,
#  'patel patel held': 620,
#  'patel held responsible': 618,
#  'held responsible state': 334,
#  'responsible state government': 703,
#  'state government poor': 785,
#  'government poor response': 291,
#  'poor response aftermath': 648,
#  'response aftermath massive': 698,
#  'aftermath massive bhuj': 14,
#  'massive bhuj earthquake': 488,
#  'bhuj earthquake gujarat': 82,
#  'earthquake gujarat earlier': 208,
#  'gujarat earlier year': 317,
#  'earlier year killed': 200,
#  'year killed people': 916,
#  'entered': 238,
#  'electoral': 222,
#  'contest': 152,
#  'february': 258,
#  'seat': 733,
#  'modi entered': 519,
#  'entered first': 239,
#  'ever electoral': 250,
#  'electoral contest': 223,
#  'contest february': 153,
#  'february election': 259,
#  'election seat': 217,
#  'seat gujarat': 736,
#  'state assembly': 780,
#  'modi entered first': 520,
#  'entered first ever': 240,
#  'first ever electoral': 270,
#  'ever electoral contest': 251,
#  'electoral contest february': 224,
#  'contest february election': 154,
#  'february election seat': 260,
#  'election seat gujarat': 218,
#  'seat gujarat state': 737,
#  'gujarat state assembly': 325,
#  'thereafter': 840,
#  'mixture': 509,
#  'deep': 177,
#  'controversy': 163,
#  'self': 749,
#  'promoted': 667,
#  'achievement': 8,
#  'modi political': 533,
#  'career thereafter': 115,
#  'thereafter remained': 841,
#  'remained mixture': 686,
#  'mixture deep': 510,
#  'deep controversy': 178,
#  'controversy self': 164,
#  'self promoted': 750,
#  'promoted achievement': 668,
#  'modi political career': 534,
#  'political career thereafter': 634,
#  'career thereafter remained': 116,
#  'thereafter remained mixture': 842,
#  'remained mixture deep': 687,
#  'mixture deep controversy': 511,
#  'deep controversy self': 179,
#  'controversy self promoted': 165,
#  'self promoted achievement': 751,
#  'role': 712,
#  'communal': 142,
#  'riot': 707,
#  'engulfed': 232,
#  'particularly': 601,
#  'questioned': 669,
#  'role chief': 713,
#  'minister communal': 500,
#  'communal riot': 143,
#  'riot engulfed': 708,
#  'engulfed gujarat': 233,
#  'gujarat particularly': 322,
#  'particularly questioned': 602,
#  'role chief minister': 714,
#  'chief minister communal': 130,
#  'minister communal riot': 501,
#  'communal riot engulfed': 144,
#  'riot engulfed gujarat': 709,
#  'engulfed gujarat particularly': 234,
#  'gujarat particularly questioned': 323,
#  'accused': 0,
#  'condoning': 149,
#  'violence': 891,
#  'least': 432,
#  'little': 453,
#  'stop': 798,
#  'killing': 408,
#  'mostly': 541,
#  'muslim': 547,
#  'ensued': 235,
#  'dozen': 195,
#  'passenger': 613,
#  'died': 189,
#  'train': 861,
#  'fire': 264,
#  'city': 134,
#  'godhra': 283,
#  'accused condoning': 1,
#  'condoning violence': 150,
#  'violence least': 892,
#  'least little': 433,
#  'little stop': 454,
#  'stop killing': 799,
#  'killing people': 409,
#  'people mostly': 622,
#  'mostly muslim': 542,
#  'muslim ensued': 548,
#  'ensued dozen': 236,
#  'dozen hindu': 196,
#  'hindu passenger': 344,
#  'passenger died': 614,
#  'died train': 190,
#  'train set': 862,
#  'set fire': 763,
#  'fire city': 265,
#  'city godhra': 135,
#  'accused condoning violence': 2,
#  'condoning violence least': 151,
#  'violence least little': 893,
#  'least little stop': 434,
#  'little stop killing': 455,
#  'stop killing people': 800,
#  'killing people mostly': 410,
#  'people mostly muslim': 623,
#  'mostly muslim ensued': 543,
#  'muslim ensued dozen': 549,
#  'ensued dozen hindu': 237,
#  'dozen hindu passenger': 197,
#  'hindu passenger died': 345,
#  'passenger died train': 615,
#  'died train set': 191,
#  'train set fire': 863,
#  'set fire city': 764,
#  'fire city godhra': 266,
#  'united': 867,
#  'declined': 174,
#  'issue': 387,
#  'diplomatic': 192,
#  'visa': 894,
#  'ground': 299,
#  'kingdom': 413,
#  'also': 31,
#  'criticized': 166,
#  'united state': 870,
#  'state declined': 782,
#  'declined issue': 175,
#  'issue diplomatic': 388,
#  'diplomatic visa': 193,
#  'visa ground': 895,
#  'ground responsible': 300,
#  'responsible riot': 700,
#  'riot united': 710,
#  'united kingdom': 868,
#  'kingdom also': 414,
#  'also criticized': 34,
#  'criticized role': 167,
#  'united state declined': 871,
#  'state declined issue': 783,
#  'declined issue diplomatic': 176,
#  'issue diplomatic visa': 389,
#  'diplomatic visa ground': 194,
#  'visa ground responsible': 896,
#  'ground responsible riot': 301,
#  'responsible riot united': 701,
#  'riot united kingdom': 711,
#  'united kingdom also': 869,
#  'kingdom also criticized': 415,
#  'also criticized role': 35,
#  'although': 36,
#  'escaped': 241,
#  'indictment': 367,
#  'censure': 120,
#  'either': 209,
#  'judiciary': 400,
#  'investigative': 376,
#  'agency': 15,
#  'close': 136,
#  'associate': 56,
#  'found': 274,
#  'guilty': 305,
#  'complicity': 146,
#  'event': 244,
#  'received': 676,
#  'lengthy': 447,
#  'jail': 390,
#  'sentence': 755,
#  'although succeeding': 37,
#  'year modi': 920,
#  'modi escaped': 521,
#  'escaped indictment': 242,
#  'indictment censure': 368,
#  'censure either': 121,
#  'either judiciary': 210,
#  'judiciary investigative': 401,
#  'investigative agency': 377,
#  'agency close': 16,
#  'close associate': 137,
#  'associate found': 57,
#  'found guilty': 275,
#  'guilty complicity': 306,
#  'complicity event': 147,
#  'event received': 245,
#  'received lengthy': 677,
#  'lengthy jail': 448,
#  'jail sentence': 391,
#  'although succeeding year': 38,
#  'succeeding year modi': 812,
#  'year modi escaped': 921,
#  'modi escaped indictment': 522,
#  'escaped indictment censure': 243,
#  'indictment censure either': 369,
#  'censure either judiciary': 122,
#  'either judiciary investigative': 211,
#  'judiciary investigative agency': 402,
#  'investigative agency close': 378,
#  'agency close associate': 17,
#  'close associate found': 138,
#  'associate found guilty': 58,
#  'found guilty complicity': 276,
#  'guilty complicity event': 307,
#  'complicity event received': 148,
#  'event received lengthy': 246,
#  'received lengthy jail': 678,
#  'lengthy jail sentence': 449,
#  'administration': 9,
#  'involvement': 384,
#  'extrajudicial': 252,
#  'variously': 877,
#  'termed': 832,
#  'encounter': 225,
#  'fake': 255,
#  'police': 627,
#  'authority': 65,
#  'modi administration': 513,
#  'administration also': 10,
#  'also accused': 32,
#  'accused involvement': 3,
#  'involvement extrajudicial': 385,
#  'extrajudicial killing': 253,
#  'killing variously': 411,
#  'variously termed': 878,
#  'termed encounter': 833,
#  'encounter fake': 226,
#  'fake encounter': 256,
#  'encounter police': 228,
#  'police authority': 628,
#  'modi administration also': 514,
#  'administration also accused': 11,
#  'also accused involvement': 33,
#  'accused involvement extrajudicial': 4,
#  'involvement extrajudicial killing': 386,
#  'extrajudicial killing variously': 254,
#  'killing variously termed': 412,
#  'variously termed encounter': 879,
#  'termed encounter fake': 834,
#  'encounter fake encounter': 227,
#  'fake encounter police': 257,
#  'encounter police authority': 229,
#  'case': 117,
#  'involved': 379,
#  'death': 168,
#  'woman': 911,
#  'men': 496,
#  'said': 724,
#  'lashkar': 416,
#  'taiba': 824,
#  'pakistan': 590,
#  'based': 66,
#  'terrorist': 835,
#  'mumbai': 544,
#  'attack': 62,
#  'alleged': 22,
#  'plotting': 624,
#  'assassinate': 49,
#  'one case': 579,
#  'case involved': 118,
#  'involved death': 380,
#  'death woman': 169,
#  'woman three': 912,
#  'three men': 847,
#  'men official': 497,
#  'official said': 574,
#  'said member': 725,
#  'member lashkar': 492,
#  'lashkar taiba': 417,
#  'taiba pakistan': 825,
#  'pakistan based': 591,
#  'based terrorist': 67,
#  'terrorist organization': 838,
#  'organization involved': 584,
#  'involved mumbai': 382,
#  'mumbai terrorist': 545,
#  'terrorist attack': 836,
#  'attack alleged': 63,
#  'alleged plotting': 23,
#  'plotting assassinate': 625,
#  'assassinate modi': 50,
#  'one case involved': 580,
#  'case involved death': 119,
#  'involved death woman': 381,
#  'death woman three': 170,
#  'woman three men': 913,
#  'three men official': 848,
#  'men official said': 498,
#  'official said member': 575,
#  'said member lashkar': 726,
#  'member lashkar taiba': 493,
#  'lashkar taiba pakistan': 418,
#  'taiba pakistan based': 826,
#  'pakistan based terrorist': 592,
#  'based terrorist organization': 68,
#  'terrorist organization involved': 839,
#  'organization involved mumbai': 585,
#  'involved mumbai terrorist': 383,
#  'mumbai terrorist attack': 546,
#  'terrorist attack alleged': 837,
#  'attack alleged plotting': 64,
#  'alleged plotting assassinate': 24,
#  'plotting assassinate modi': 626,
#  'repeated': 690,
#  'indispensable': 370,
#  'within': 908,
#  'reintegration': 679,
#  'mainstream': 476,
#  'modi repeated': 537,
#  'repeated political': 691,
#  'political success': 638,
#  'success gujarat': 814,
#  'gujarat however': 318,
#  'however made': 351,
#  'made indispensable': 472,
#  'indispensable leader': 371,
#  'leader within': 427,
#  'within bjp': 909,
#  'bjp hierarchy': 92,
#  'hierarchy led': 341,
#  'led reintegration': 442,
#  'reintegration political': 680,
#  'political mainstream': 635,
#  'modi repeated political': 538,
#  'repeated political success': 692,
#  'political success gujarat': 639,
#  'success gujarat however': 815,
#  'gujarat however made': 319,
#  'however made indispensable': 352,
#  'made indispensable leader': 473,
#  'indispensable leader within': 372,
#  'leader within bjp': 428,
#  'within bjp hierarchy': 910,
#  'bjp hierarchy led': 93,
#  'hierarchy led reintegration': 342,
#  'led reintegration political': 443,
#  'reintegration political mainstream': 681,
#  'leadership': 429,
#  'secured': 746,
#  'significant': 770,
#  'december': 171,
#  'winning': 905,
#  'including': 353,
#  'leadership bjp': 430,
#  'bjp secured': 101,
#  'secured significant': 747,
#  'significant victory': 771,
#  'victory december': 884,
#  'december legislative': 172,
#  'election winning': 220,
#  'winning seat': 906,
#  'seat chamber': 734,
#  'chamber including': 124,
#  'including seat': 354,
#  'seat modi': 738,
#  'leadership bjp secured': 431,
#  'bjp secured significant': 102,
#  'secured significant victory': 748,
#  'significant victory december': 772,
#  'victory december legislative': 885,
#  'december legislative assembly': 173,
#  'assembly election winning': 55,
#  'election winning seat': 221,
#  'winning seat chamber': 907,
#  'seat chamber including': 735,
#  'chamber including seat': 125,
#  'including seat modi': 355,
#  'projecting': 664,
#  'manifesto': 480,
#  'growth': 302,
#  'development': 186,
#  'victorious': 880,
#  'total': 855,
#  'prevailed': 652,
#  'poll': 643,
#  'garnering': 277,
#  'projecting manifesto': 665,
#  'manifesto growth': 481,
#  'growth development': 303,
#  'development gujarat': 187,
#  'gujarat bjp': 309,
#  'bjp victorious': 103,
#  'victorious state': 881,
#  'seat total': 739,
#  'total party': 856,
#  'party prevailed': 609,
#  'prevailed poll': 653,
#  'poll garnering': 644,
#  'garnering seat': 278,
#  'projecting manifesto growth': 666,
#  'manifesto growth development': 482,
#  'growth development gujarat': 304,
#  'development gujarat bjp': 188,
#  'gujarat bjp victorious': 310,
#  'bjp victorious state': 104,
#  'victorious state assembly': 882,
#  'state assembly election': 781,
#  'assembly election seat': 54,
#  'election seat total': 219,
#  'seat total party': 740,
#  'total party prevailed': 857,
#  'party prevailed poll': 610,
#  'prevailed poll garnering': 654,
#  'poll garnering seat': 645,
#  'time': 852,
#  'returned': 704,
#  'time modi': 853,
#  'modi contest': 517,
#  'contest returned': 155,
#  'returned chief': 705,
#  'time modi contest': 854,
#  'modi contest returned': 518,
#  'contest returned chief': 156,
#  'returned chief minister': 706}

# %%
 #TFIDF
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(ngram_range=(1,1),max_features=4)
X = cv.fit_transform(corpus)

# %%
corpus[0]
# Out:
# 'narendra modi born september vadnagar india indian politician government official rose become senior leader bharatiya janata party bjp'

# %%
print(X[0].toarray())
# Out:
# [[0.79043454 0.         0.61254652 0.        ]]
